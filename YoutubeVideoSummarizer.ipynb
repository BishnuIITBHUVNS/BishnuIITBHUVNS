# %% [markdown]
# <a href="https://colab.research.google.com/github/BishnuIITBHUVNS/BishnuIITBHUVNS/blob/main/YoutubeVideoSummarizer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install youtube_transcript_api
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 30.8 MB/s eta 0:00:00
# ...

# %%
from youtube_transcript_api import YouTubeTranscriptApi

# %%
def get_video_id(url_link):
  return url_link.split("watch?v=")[-1]

# %%
video=input("Enter the video link: ")
# Out:
# Enter the video link: https://www.youtube.com/watch?v=hyvwkrWWB0s

# %%
video_id=get_video_id(video)

# %%
video_id
# Out:
# 'hyvwkrWWB0s'

# %%
transcript = YouTubeTranscriptApi.get_transcript(video_id)

# %%
transcript
# Out:
# [{'text': 'hello my name is Dr gajendra purohit and',
#   'start': 0.24,
#   'duration': 3.32},
#  {'text': "you're watching our YouTube channel",
#   'start': 2.159,
#   'duration': 2.961},
#  {'text': 'where I upload videos for engineering',
#   'start': 3.56,
#   'duration': 3.4},
#  {'text': "mathematics BSC and if you're preparing",
#   'start': 5.12,
#   'duration': 4.36},
#  {'text': 'for any competitive exam where higher',
#   'start': 6.96,
#   'duration': 4.12},
#  {'text': 'mathematics is asked my YouTube channel',
#   'start': 9.48,
#   'duration': 4.0},
#  {'text': 'is very helpful for you I have started',
#   'start': 11.08,
#   'duration': 4.519},
#  {'text': 'uploading Vector calculus and today I am',
#   'start': 13.48,
#   'duration': 4.32},
#  {'text': 'going to explain to you the concept of',
#   'start': 15.599,
#   'duration': 3.641},
#  {'text': 'line integral the line integral is',
#   'start': 17.8,
#   'duration': 3.719},
# ...

# %%
transcript_joined="".join(line['text']for line in transcript)

# %%
transcript_joined
# Out:
# "hello my name is Dr gajendra purohit andyou're watching our YouTube channelwhere I upload videos for engineeringmathematics BSC and if you're preparingfor any competitive exam where highermathematics is asked my YouTube channelis very helpful for you I have starteduploading Vector calculus and today I amgoing to explain to you the concept ofline integral the line integral iswithin Vector integration then we willstudy the greens theorem as well as theStokes theorem where the problems of theline integral and the difficulties weface while solving it so we convert itinto double integral by using thesetheorems we'll study that in upcomingclasses but before that it's importantto know concept of line integral becausesometimes we're asked to verify greensor Stokes is theorem so we need to useLINE integrals as well as doubleintegration and then we need to verifyit so it's important to know lineintegral I'm going to teach about theconcept of line integral in today'sclass[Music][Music]let's di
# ...

# %%
# !pip install git+https://github.com/babthamotharan/rpunct.git@patch-2
# Out:
# ...
#   Cloning https://github.com/babthamotharan/rpunct.git (to revision patch-2) to /tmp/pip-req-build-ojyzj1c3
#   Running command git clone --filter=blob:none --quiet https://github.com/babthamotharan/rpunct.git /tmp/pip-req-build-ojyzj1c3
#   Running command git checkout -b patch-2 --track origin/patch-2
#   Switched to a new branch 'patch-2'
#   Branch 'patch-2' set up to track remote branch 'patch-2' from 'origin'.
#   Resolved https://github.com/babthamotharan/rpunct.git to commit a87b93410ca782657abb4e34df9159e6e47ac9ec
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 15.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.4/42.4 kB 3.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 3.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 3.5 MB/s eta 0:00:00
# ...

# %%
from rpunct import RestorePuncts
rpunct = RestorePuncts()
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.25k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/436M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/530 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/436M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]

# %%
results=rpunct.punctuate(transcript_joined)
# Out:
# /usr/local/lib/python3.11/dist-packages/simpletransformers/ner/ner_model.py:1643: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast():

# %%
print(results)
# Out:
# Hello, my name is Dr Gajendra Purohit Andyou're watching our YouTube channelwhere I upload videos for engineeringmathematics BSC And if you're preparingfor any competitive exam where highermathematics is asked, my YouTube channelis very helpful for you. I have starteduploading Vector calculus and today I amgoing to explain to you the concept ofline integral. the line integral iswithin Vector integration. Then we willstudy the Greens Theorem as well as theStokes theorem where the problems of theline integral and the difficulties weface while solving it. So we convert itinto double integral by using thesetheorems. We'll study that in upcomingclasses, but before that, it's importantto know concept of line integral becausesometimes we're asked to verify Greensor Stokes is theorem. So we need to useLINE integrals as well as doubleintegration. and then we need to verifyit So it's important to know lineintegral. I'm going to teach about theconcept of line integral in today'sclass[Music][Mus
# ...

# %%
# !pip install -q -U google-generativeai

# %%
import pathlib
import textwrap
import os
import google.generativeai as genai

from IPython.display import display
from IPython.display import Markdown


def to_markdown(text):
    text = text.replace("•", "  *")
    return Markdown(textwrap.indent(text, "> ", predicate=lambda _: True))

# %%
#from google.colab import userdata

# %%
# Import the Python SDK
import google.generativeai as genai
# Used to securely store your API key
from google.colab import userdata

GOOGLE_API_KEY=userdata.get('GOOGLE_API_KEY')
genai.configure(api_key=GOOGLE_API_KEY)

# %%
#model = genai.GenerativeModel('gemini-pro')

# %%
model = genai.GenerativeModel("gemini-1.5-flash")

# %%
response = model.generate_content("Summarize for me" + transcript_joined)
print(response.text)
# Out:
# This YouTube video by Dr. Gajendra Purohit explains line integrals in vector calculus.  He begins by defining a line integral as an integral evaluated along a curve, emphasizing that it involves integration with respect to a single variable.  If multiple variables (x, y, z) are present, the problem must provide information to reduce it to a single variable.
#
# The video covers several key aspects:
#
# * **Properties of line integrals:**  Similar to definite integrals, changing the limits introduces a negative sign.  Parametric forms, where x, y, and z are functions of a parameter (often t), are used to simplify integration.
#
# * **Solving line integrals:**  The video demonstrates solving line integrals by converting them to a single variable through substitution and applying appropriate limits.  Examples show how to handle integrals involving both x and y by expressing one variable in terms of the other.
#
# ...
